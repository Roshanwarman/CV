# %% [markdown]
# # Problem Set 2: CPSC 475

# %% [markdown]
# Roshan Warman

# %% [markdown]
# ## Question 1

# %% [markdown]
# a) For a single neuron with an initial membrane potential of $-60 \text{mV}$ and a leak voltage of $-70 \text{mV}$, there is a rapid decay in membrane potential with no injected current. For an injected current of $1
# \text{nA}$, there was no change in the membrane potential. This is because

# %%
from nsimulator import nsimulator

single = nsimulator(1)
single.set_mpotential(0, -60)


single.set_Ie(0, 0)

single.simulate_timeinterval(0.0, 0.2)

single.plot_membranepotentials([0])
